# %% [markdown]
# <a href="https://colab.research.google.com/github/CyberKaps/AI-ML/blob/main/class_4_intro_to_tensor_and_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import time
import math


#check if GUP is available or not
print(f"pytorch version: {torch.__version__}")
print(f"GPU available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
  print(f"GPU Name: {torch.cuda.get_device_name(0)}")
else:
  print("No GPU available")

print("\nsetup complete")
# Out:
# pytorch version: 2.10.0+cu128
# GPU available: True
# GPU Name: Tesla T4
#
# setup complete

# %%
# A scalar - just a number
kalpesh_age = torch.tensor(21.0)

# %%
print(kalpesh_age)
# Out:
# tensor(21.)

# %%
print(f"The value of kalpesh_age is: {kalpesh_age}")
print(f"The data type of kalpesh_age is: {kalpesh_age.dtype}")
# Out:
# The value of kalpesh_age is: 21.0
# The data type of kalpesh_age is: torch.float32

# %%
# A vector - a list of numbers
vector = torch.tensor([1.0, 2.0, 3.0, 4.0])

# %%
print(vector)
# Out:
# tensor([1., 2., 3., 4.])

# %%
print(vector.dim())
# Out:
# 1

# %%
print(kalpesh_age.dim())
# Out:
# 0

# %%
# A matrix - grid of numbers
matrix = torch.tensor([[1, 2, 3],
                      [4, 5, 6]])
print(f"Matrix:\n{matrix}")
print(f"  Shape: {matrix.shape}")   # torch.Size([2, 3])
print(f"  Dimensions: {matrix.dim()}") #
# Out:
# Matrix:
# tensor([[1, 2, 3],
#         [4, 5, 6]])
#   Shape: torch.Size([2, 3])
#   Dimensions: 2

# %%
# A 3D tensor - a cube of numbers
tensor_3d = torch.zeros(2, 3, 4)
print(f"3D Tensor shape: {tensor_3d.shape}")  # [2, 3, 4]
print(f"  Dimensions: {tensor_3d.dim()}")   # 3
# Out:
# 3D Tensor shape: torch.Size([2, 3, 4])
#   Dimensions: 3

# %%
# A 4D tensor - like a batch going through multi-head attentions
tensor_4d = torch.zeros(8, 12, 3, 64)
print(f"4D Tensor shape: {tensor_4d.shape}")
print(f"  Dimensions: {tensor_4d.dim()}")
# Out:
# 4D Tensor shape: torch.Size([8, 12, 3, 64])
#   Dimensions: 4

# %%
# If you're passing numbers as dimensions → zeros()
# If you're passing numbers as actual data → tensor()
